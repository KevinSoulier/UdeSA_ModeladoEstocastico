# %% [markdown]
# # Modelado Estocástico
# ## Clase 03 - Análisis detallado de los valores de la Regresión Lineal de statsmodel.

# %% [markdown]
# Para utilizar regresiones lineales podemos importar tanto `statsmodels.api` como `statsmodels.formula.api`.
# En el Notebook vamos a implementar un ejemplo con la sintaxis de parámetros matriciales.
#
# Poseen algunas diferencias, la sintaxis de las fórmulas en `statsmodels.api` es matricial, utilizano arrays o DataFrames mientras que en `statsmodel.formula.api` es a través de strings (al estilo de R) y solo con DFs.
#
# (Para más información puede consultarse la documentación de statsmodel [https://www.statsmodels.org/stable/api.html])

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Carga del archivo `ceo.xlsx` disponible en la carpeta **Bases de Datos** del Campus. (Los datos son coincidentes con los utilizados en la Ejercitación 3).

# %%
df = pd.read_excel('ceo.xlsx')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\kevin\source\repos\UdeSA_ModeladoEstocastico\.venv\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1406, in _gcd_import(name, package, level)
#    1404     if level > 0:
#    1405         name = _resolve_name(name, package, level)
# -> 1406     return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369             module = sys.modules.get(name, _NEEDS_LOADING)
#    1370             if module is _NEEDS_LOADING:
# -> 1371                 return _find_and_load_unlocked(name, import_)
#    1372
#
# File <frozen importlib._bootstrap>:1335, in _find_and_load_unlocked(name, import_)
#    1333     spec = _find_spec(name, path)
#    1334     if spec is None:
# -> 1335         raise ModuleNotFoundError(f'{_ERR_MSG_PREFIX}{name!r}', name=name)
#    1336     else:
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel('ceo.xlsx')
#       2 print(df.head())
#
# File c:\Users\kevin\source\repos\UdeSA_ModeladoEstocastico\.venv\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File c:\Users\kevin\source\repos\UdeSA_ModeladoEstocastico\.venv\Lib\site-packages\pandas\io\excel\_base.py:1621, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1618 self.engine = engine
#    1619 self.storage_options = storage_options
# -> 1621 self._reader = self._engines[engine](
#    1622     self._io,
#    1623     storage_options=storage_options,
#    1624     engine_kwargs=engine_kwargs,
#    1625 )
#
# File c:\Users\kevin\source\repos\UdeSA_ModeladoEstocastico\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:559, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 @doc(storage_options=_shared_docs["storage_options"])
#     542 def __init__(
#     543     self,
#    (...)    546     engine_kwargs: dict | None = None,
#     547 ) -> None:
#     548     """
#     549     Reader using openpyxl engine.
#     550
#    (...)    557         Arbitrary keyword arguments passed to excel engine.
#     558     """
# --> 559     import_optional_dependency("openpyxl")
#     560     super().__init__(
#     561         filepath_or_buffer,
#     562         storage_options=storage_options,
#     563         engine_kwargs=engine_kwargs,
#     564     )
#
# File c:\Users\kevin\source\repos\UdeSA_ModeladoEstocastico\.venv\Lib\site-packages\pandas\compat\_optional.py:161, in import_optional_dependency(name, extra, min_version, errors)
#     159 except ImportError as err:
#     160     if errors == "raise":
# --> 161         raise ImportError(msg) from err
#     162     return None
#     164 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: `Import openpyxl` failed.  Use pip or conda to install the openpyxl package.

# %% [markdown]
# - Utilizamos el modelo OLS(_Ordinary Least Squares_) de statsmodel para crear el modelo de regresión lineal. Y analizamos sus valores. Para el primer ejemplo lo vamos a generar utilizando `statsmodel.api` con la sintaxis usual.
# Incorporamos los interceptos con `add_constant` para agregar la columna de unos a X. Dado que `statsmodel.api` no la estima automáticamente si no se la incluye explícitamente el ajuste resultante puede ser incorrecto.

# %%
X = sm.add_constant(df["Ganancias"])
y = df["Compensacion_CEO"]
X
# Out:
#     const  Ganancias
# 0     1.0      357.0
# 1     1.0       48.0
# 2     1.0      932.0
# 3     1.0      366.0
# 4     1.0       83.0
# ..    ...        ...
# 65    1.0      327.0
# 66    1.0      409.0
# 67    1.0      117.0
# 68    1.0      179.0
# 69    1.0      234.0
#
# [70 rows x 2 columns]

# %%
modelo1 = sm.OLS(y, X).fit()

print(modelo1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Compensacion_CEO   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     52.24
# Date:                Sat, 11 Jul 2026   Prob (F-statistic):           5.50e-10
# Time:                        12:03:33   Log-Likelihood:                -73.655
# No. Observations:                  70   AIC:                             151.3
# Df Residuals:                      68   BIC:                             155.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6000      0.112      5.342      0.000       0.376       0.824
# Ganancias      0.0008      0.000      7.228      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       21.745   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.165
# Skew:                           1.136   Prob(JB):                     1.40e-08
# Kurtosis:                       5.691   Cond. No.                     1.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Los estimadores de la regresión están guardados en la Serie `modelo1.params`

# %%
modelo1.params
# Out:
# const        0.599965
# Ganancias    0.000842
# dtype: float64

# %% [markdown]
# El intercepto (u ordenada al origen) podrá observarse en modelo1.params.iloc[0] y la pendiente en el parámetro con el nombre de la columna con los datos ingresados en X, en este caso, `Ganancias` o en params.iloc[1].

# %%
print(f"Intercepto: {modelo1.params.iloc[0]} \nPendiente: {modelo1.params['Ganancias']}")
# Out:
# Intercepto: 0.5999648988232877
# Pendiente: 0.0008423268484880064

# %% [markdown]
# ### Descomposición de la suma de cuadrados (modelo de regresión lineal simple)
# $
# \text{RSS} = \text{TSS} - \text{ESS}
# $
#
# $
# \sum_{i=1}^{n} e_i^2 = \sum_{i=1}^{n}(y_i - \bar{y})^2 - \hat{\beta}^2 \sum_{i=1}^{n}(x_i - \bar{x})^2
# $
#
# donde:
#
# - $\text{RSS}$ = Residual Sum of Squares
# - $\text{TSS}$ = Total Sum of Squares
# - $\text{ESS}$ = Explained Sum of Squares

# %%
tss = modelo1.centered_tss
ess = modelo1.ess
rss = modelo1.ssr
print(f"TSS: {tss} \nESS: {ess} \nRSS: {rss}")
# Out:
# TSS: 59.44585714285713
# ESS: 25.82797005571605
# RSS: 33.61788708714108

# %% [markdown]
# Podemos validar que la diferencia entre TSS y ESS sea efectivamente la RSS obtenida:

# %%
tss-ess
# Out:
# np.float64(33.61788708714108)

# %% [markdown]
# ### $R^2$
# A continuación vamos a ver cómo obtener el $R^2$ (R cuadrado) de diferentes formas:
#
# El que guarda el modelo:

# %%
modelo1.rsquared
# Out:
# np.float64(0.43447889049101684)

# %% [markdown]
# Por definición:

# %%
ess/tss
# Out:
# np.float64(0.4344788904910168)

# %% [markdown]
# Utilizando  $ESS = TSS - RSS$

# %%
1 - rss / tss
# Out:
# np.float64(0.43447889049101684)

# %% [markdown]
# Utilizando la correlación real entre `y` y `y_hat`
#
# Recordemos que $\hat{y}$  (`y_hat`) es el valor predicho de $y$. Podemos utilizar `.fittedvalues` para obtenerlo

# %%
y_hat = modelo1.fittedvalues
y_hat.head()
# Out:
# 0    0.900676
# 1    0.640397
# 2    1.385014
# 3    0.908257
# 4    0.669878
# dtype: float64

# %% [markdown]
# Cuadrado de la correlación real entre `y` y `y_hat`:

# %%
correlacion = np.corrcoef(y, y_hat)[0, 1]
correlacion ** 2
# Out:
# np.float64(0.434478890491017)

# %% [markdown]
# ### Estimador $s^2$ del parámetro $\sigma^2$

# %%
modelo1.scale
# Out:
# np.float64(0.494380692457957)

# %% [markdown]
# Calculado como   $s^2 = RSS / (n - k)$:

# %%
rss/modelo1.df_resid
# Out:
# np.float64(0.494380692457957)

# %% [markdown]
# Cuya raíz cuadrada es el desvío estándar $\sigma$:

# %%
np.sqrt(modelo1.scale)
# Out:
# np.float64(0.7031221035196924)

# %% [markdown]
# ### Residuos

# %%
modelo1.resid
# Out:
# 0    -0.200676
# 1     0.059603
# 2    -0.585014
# 3    -0.208257
# 4     0.130122
#         ...
# 65   -0.275406
# 66    0.755523
# 67    1.701483
# 68   -0.350741
# 69    0.402931
# Length: 70, dtype: float64

# %% [markdown]
# O, manualmente:

# %%
y - y_hat
# Out:
# 0    -0.200676
# 1     0.059603
# 2    -0.585014
# 3    -0.208257
# 4     0.130122
#         ...
# 65   -0.275406
# 66    0.755523
# 67    1.701483
# 68   -0.350741
# 69    0.402931
# Length: 70, dtype: float64

# %% [markdown]
# ### Verificamos que se cumplen las CPO del problema de MCO (OLS):
#
# a. La suma de los residuos es cero (y consecuentemente, tambien su media):

# %%
modelo1.resid.sum()
# Out:
# np.float64(2.353672812205332e-14)

# %%
modelo1.resid.mean()
# Out:
# np.float64(3.3623897317219026e-16)

# %% [markdown]
# b. Los residuos no estan correlacionados con X ('Ganancias').
#
#   Obtengo nombres, valores y armo el DF dfX, incluyendo los residuos.

# %%
col_names = modelo1.model.exog_names
col_names
# Out:
# ['const', 'Ganancias']

# %%
values = modelo1.model.exog
values[:10]
# Out:
# array([[  1., 357.],
#        [  1.,  48.],
#        [  1., 932.],
#        [  1., 366.],
#        [  1.,  83.],
#        [  1.,  22.],
#        [  1.,  67.],
#        [  1., 413.],
#        [  1., 496.],
#        [  1., 458.]])

# %%
dfX = pd.DataFrame(modelo1.model.exog, columns=col_names)
dfX['res'] = modelo1.resid
dfX
# Out:
#     const  Ganancias       res
# 0     1.0      357.0 -0.200676
# 1     1.0       48.0  0.059603
# 2     1.0      932.0 -0.585014
# 3     1.0      366.0 -0.208257
# 4     1.0       83.0  0.130122
# ..    ...        ...       ...
# 65    1.0      327.0 -0.275406
# 66    1.0      409.0  0.755523
# 67    1.0      117.0  1.701483
# 68    1.0      179.0 -0.350741
# 69    1.0      234.0  0.402931
#
# [70 rows x 3 columns]

# %% [markdown]
# ### Covarianza entre N y los residuos, debe dar 0. (En este caso su orden de magnitud es $10^{-14}$, una aproximación más que razonable a 0)

# %%
dfX.cov().loc['Ganancias', 'res']
# Out:
# np.float64(-5.876665108716543e-14)

# %% [markdown]
# - Graficamos Residuos vs Ganancias:

# %%
plt.scatter(df["Ganancias"], modelo1.resid)
plt.axhline(0, color='gray', linestyle='--')
plt.xlabel("Ganancias")
plt.ylabel("Residuos")
plt.title("Residuos vs. Ganancias")
plt.show()

# %% [markdown]
#  - Graficamos la recta estimada:

# %%
predicts = modelo1.predict(X)
plt.scatter(df['Ganancias'], y, label = 'Datos', color='blue')
plt.plot(df['Ganancias'], predicts, color='red', label='Regresión lineal')
plt.xlabel('Ganancias en millones')
plt.ylabel('Compensación al CEO en millones')
plt.title('Regresión Lineal')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Valor predicho de `Comp_CEO` para un valor de Ganancias particular, por ejemplo, para 500 millones de ganancias:
#
# Utilizando el desarrollo "manual":

# %%
intercepto = modelo1.params.iloc[0]
pendiente = modelo1.params['Ganancias']
Ganancias_valor = 500

y_hat_500 = intercepto + pendiente * Ganancias_valor
y_hat_500
# Out:
# np.float64(1.021128323067291)

# %% [markdown]
# Utilizando el predictor:

# %%
ganancia_a_predecir = [1,500]
y_hat_500 = modelo1.predict(ganancia_a_predecir)
y_hat_500
# Out:
# array([1.02112832])

# %% [markdown]
# Utilizando el vector de coeficientes estimados:

# %%
beta = modelo1.params

nuevo_punto = [1, 500]
np.dot(nuevo_punto, beta)
# Out:
# np.float64(1.021128323067291)

# %% [markdown]
# ### Matriz de varianzas y Covarianzas de los beta_sombrero
# Statsmodels guarda las varianzas y covarianzas de los estimadores

# %%
modelo1.cov_params()
# Out:
#               const     Ganancias
# const      0.012615 -8.684073e-06
# Ganancias -0.000009  1.358102e-08

# %% [markdown]
# Notar que en `modelo1.summary` vemos los Std Err en la segunda columna, que es la raiz de la varianza ($\sqrt{0.012615}=0.112$)

# %%
print(modelo1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Compensacion_CEO   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     52.24
# Date:                Sat, 11 Jul 2026   Prob (F-statistic):           5.50e-10
# Time:                        12:03:34   Log-Likelihood:                -73.655
# No. Observations:                  70   AIC:                             151.3
# Df Residuals:                      68   BIC:                             155.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6000      0.112      5.342      0.000       0.376       0.824
# Ganancias      0.0008      0.000      7.228      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       21.745   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.165
# Skew:                           1.136   Prob(JB):                     1.40e-08
# Kurtosis:                       5.691   Cond. No.                     1.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Standard Errors

# %%
modelo1.bse
# Out:
# const        0.112318
# Ganancias    0.000117
# dtype: float64

# %% [markdown]
# ### Y sombrero e intervalo de confianza para Y sombrero (Banda de confianza Y Banda de predicción)
# Cálculo de un IC para el y_hat $\bar{y}$  y un IC para "y" (un "y" futuro)

# %%
pred = modelo1.get_prediction()
IC_pred = pred.summary_frame(alpha = 0.05)

# %%
IC_pred.head()
# Out:
#        mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  0.900676  0.090254       0.720576       1.080776     -0.513895
# 1  0.640397  0.108688       0.423514       0.857280     -0.779326
# 2  1.385014  0.090692       1.204040       1.565987     -0.029668
# 3  0.908257  0.089877       0.728909       1.087604     -0.506218
# 4  0.669878  0.106148       0.458063       0.881693     -0.749079
#
#    obs_ci_upper
# 0      2.315246
# 1      2.060119
# 2      2.799695
# 3      2.322731
# 4      2.088835

# %% [markdown]
# Recordemos que `np.allclose` compara dos valores o arrays y devuelve `True` si están dentro de un umbral de tolerancia especificado. Por ejemplo, si cotejamos `IC_pred['mean]` del `summary_frame` con $\bar{y}$:

# %%
np.allclose(IC_pred['mean'], y_hat)
# Out:
# True

# %% [markdown]
# Replicamos _a mano_ cada columna del summary_frame. La primera columna es el $\hat{y}$, el valor sobre la recta estimada dado x.

# %% [markdown]
# La segunda columna será el Standard Error del $\hat{y}$.
# Para obtenerlo:
# 1. Obtenemos la varianza del $\hat{y}$
#
# Sabemos que
#
# $\hat{y} = \hat{\alpha} + \hat{\beta} x$
#
# Y que
#
# $
# \operatorname{Var}(\hat{y}) = \operatorname{Var}(\hat{\alpha}) + x^2  \operatorname{Var}(\hat{\beta}) + 2x  \operatorname{Cov}(\hat{\alpha}, \hat{\beta})
# $

# %%
modelo1.cov_params()
# Out:
#               const     Ganancias
# const      0.012615 -8.684073e-06
# Ganancias -0.000009  1.358102e-08

# %%
params = modelo1.cov_params().values
params
# Out:
# array([[ 1.26154123e-02, -8.68407339e-06],
#        [-8.68407339e-06,  1.35810239e-08]])

# %%
var_y_hat = params[0,0] + params[1,1]*(df['Ganancias']**2) + 2*df['Ganancias']*params[1,0]
var_y_hat.head()
# Out:
# 0    0.008146
# 1    0.011813
# 2    0.008225
# 3    0.008078
# 4    0.011267
# Name: Ganancias, dtype: float64

# %% [markdown]
# 2. Calculo standard error (al $\hat{y}$), correspondiente a la segunda columna `mean_se` del `summary_frame`. Luego, las cotejo:

# %%
se_y_hat=var_y_hat**0.5
np.allclose(IC_pred['mean_se'], se_y_hat)
# Out:
# True

# %% [markdown]
# La tercera y cuarta columnas son la BANDA DE CONFIANZA de $\hat{y}$ del 95%.
#
# Grados de libertad $n - k$:

# %%
dfreed = modelo1.df_resid
alpha = 0.05
t_val = stats.t.ppf(1 - alpha/2, dfreed)
IC_y_hat_low = y_hat - t_val * se_y_hat
IC_y_hat_up  = y_hat + t_val * se_y_hat

# %% [markdown]
# Cotejo las tercera y cuarta columnas:

# %%
np.allclose(IC_pred['mean_ci_lower'], IC_y_hat_low)
# Out:
# True

# %%
np.allclose(IC_pred['mean_ci_upper'], IC_y_hat_up)
# Out:
# True

# %% [markdown]
# Las últimas dos columnas, quinta y sexta, son LA BANDA DE PREDICCIÓN
#
# Agregan la varianza del residuo ($e$):
#
# $y = \hat{y} + e$
#
# Y la varianza de $y$:
#
# $\operatorname{Var}(y) = \operatorname{Var}(\hat{y}) + \operatorname{Var}(e)$
#
# Donde $\operatorname{Var}(e)$ es `modelo1.mse_resid`, que es `modelo1.scale` que es $s^2$, el estimador de sigma cuadrado) dividido ($n-k$)

# %%
sigma2_hat = modelo1.mse_resid
se_pred = (var_y_hat + sigma2_hat) ** 0.5

IC_y_pred_low = y_hat - t_val * se_pred
IC_y_pred_up  = y_hat + t_val * se_pred

# %% [markdown]
# Cotejamos la quinta columna:

# %%
np.allclose(IC_pred['obs_ci_lower'], IC_y_pred_low)
# Out:
# True

# %% [markdown]
# Y la sexta columna:

# %%
np.allclose(IC_pred['obs_ci_upper'], IC_y_pred_up)
# Out:
# True

# %% [markdown]
# ### Gráfico del IC de la BANDA DE CONFIANZA y de la BANDA DE PREDICCION

# %%
Y = df['Compensacion_CEO']
X = sm.add_constant(df[['Ganancias']])

pred = modelo1.get_prediction()
IC_pred = pred.summary_frame(alpha = 0.05)
IC_pred
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0   0.900676  0.090254       0.720576       1.080776     -0.513895
# 1   0.640397  0.108688       0.423514       0.857280     -0.779326
# 2   1.385014  0.090692       1.204040       1.565987     -0.029668
# 3   0.908257  0.089877       0.728909       1.087604     -0.506218
# 4   0.669878  0.106148       0.458063       0.881693     -0.749079
# ..       ...       ...            ...            ...           ...
# 65  0.875406  0.091587       0.692646       1.058165     -0.539505
# 66  0.944477  0.088225       0.768426       1.120527     -0.469584
# 67  0.698517  0.103775       0.491437       0.905597     -0.719740
# 68  0.750741  0.099708       0.551777       0.949705     -0.666354
# 69  0.797069  0.096410       0.604686       0.989453     -0.619117
#
#     obs_ci_upper
# 0       2.315246
# 1       2.060119
# 2       2.799695
# 3       2.322731
# 4       2.088835
# ..           ...
# 65      2.290317
# 66      2.358537
# 67      2.116775
# 68      2.167837
# 69      2.213256
#
# [70 rows x 6 columns]

# %% [markdown]
# Tomamos las columnas de interés:

# %%
yhat = IC_pred['mean']
mean_ci_lower = IC_pred['mean_ci_lower']
mean_ci_upper = IC_pred['mean_ci_upper']
obs_ci_lower  = IC_pred['obs_ci_lower']
obs_ci_upper  = IC_pred['obs_ci_upper']

# %% [markdown]
# Graficamos:

# %%
idx = np.argsort(X['Ganancias'])
x_val = X['Ganancias'].iloc[idx]
yhat_val = yhat.iloc[idx]
lcb_mean = mean_ci_lower.iloc[idx]
ucb_mean = mean_ci_upper.iloc[idx]
lcb_obs = obs_ci_lower.iloc[idx]
ucb_obs = obs_ci_upper.iloc[idx]

plt.scatter(X['Ganancias'], Y, label='Datos observados', color='black', alpha=0.7, zorder=5)

plt.plot(x_val, yhat_val, color='RED', label='Predicción puntual', linewidth=2, zorder=4)

plt.fill_between(x_val, lcb_mean, ucb_mean, color='green', alpha=0.3, label='IC Confianza (95%)')
plt.fill_between(x_val, lcb_obs, ucb_obs, color='magenta', alpha=0.2, label='IC Predicción (95%)')

plt.xlabel('Ganancias', fontsize=12)
plt.ylabel('Compensación_CEO', fontsize=12)
plt.title('Bandas de confianza y de predicción', fontsize=14, pad=15)

plt.legend()

plt.grid(True, linestyle=':', alpha=0.8)
plt.tight_layout()
plt.show()
